# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import time
import pandas as pd

# %%
def setup_driver():
    options = webdriver.ChromeOptions()
    options.add_argument('--headless')  # Run in headless mode
    options.add_argument('--no-sandbox')
    options.add_argument('--disable-dev-shm-usage')
    service = Service('C:/Users/user/Desktop/WebScrapingProject/chromedriver.exe')
    driver = webdriver.Chrome(service=service, options=options)
    return driver

# %%
def get_top_twitch_categories(k=10):
    # Set up Chrome WebDriver
    driver = setup_driver()
    
    url = 'https://www.twitch.tv/directory?sort=VIEWER_COUNT'
    driver.get(url)
    time.sleep(3)  # Wait for page to load
    
    # Find category elements
    categories = driver.find_elements(By.XPATH, '//a[starts-with(@data-a-target, "card-")][h2]')
    top_k_categories = []
    for cat in categories[:k]:
        # Try to get the category name from a span or h2 element
        try:
            # Sometimes the category name is in a span with data-a-target="tw-core-button-label-text"
            name_elem = cat.find_element(By.XPATH, './/h2')
            if "viewers" in name_elem.text.lower():
                continue  # Skip if it contains viewer count
            name = name_elem.text
            link = cat.get_attribute('href')
            print(f"Category: {name}, Link: {link}")
            top_k_categories.append((name, link))
        except Exception:
            continue
    driver.quit()
    return top_k_categories

# %%
def scrape_channels_from_categories(top_categories, max_channels_per_category=20):
    driver = setup_driver()
    all_channels = []

    # top_categories = top_categories[:1]  # Limit to top 1 category for brevity
    for name, link in top_categories:
        print(f"Scraping category: {name}")
        driver.get(link + "?sort=VIEWER_COUNT")
        time.sleep(3)  # Wait for page to load

        # Set language filter to English if the option is available
        try:
            # Open the language filter menu first
            filter_button = driver.find_element(
                By.XPATH,
                '//button[.//div[@data-a-target="tw-core-button-label-text" and contains(text(), "Language")]]'
            )
            filter_button.click()
            time.sleep(1)
            english_label = driver.find_element(
                By.XPATH,
                '//label[.//div[text()="English"]]'
            )
            # Find the associated checkbox input
            checkbox = english_label.find_element(
                By.XPATH,
                './preceding-sibling::input[@type="checkbox"]'
            )
            # Only click if not already checked
            if not checkbox.is_selected():
                english_label.click()
                time.sleep(1)  # Wait for the page to reload with the filter applied
            else:
                print("English language filter already checked, skipping click.")
            print("Set language filter to English.")
        except Exception:
            print("English language filter not found or could not be set.")

        # Scroll to load more channels if needed
        last_height = driver.execute_script("return document.body.scrollHeight")
        while True:
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(2)
            new_height = driver.execute_script("return document.body.scrollHeight")
            if new_height == last_height or len(driver.find_elements(
                By.XPATH, '//a[@data-a-target="preview-card-channel-link"]')) >= max_channels_per_category:
                break
            last_height = new_height

        channel_elements = driver.find_elements(
            By.XPATH, '//a[@data-a-target="preview-card-channel-link"]')
        for elem in channel_elements[:max_channels_per_category]:
            href = elem.get_attribute('href')
            channelId = href.split('/')[-1]
            print(f"Category: {name}, Channel ID: {channelId}, URL: {href}")
            all_channels.append({'category': name, 'href': href, 'channelId': channelId})

    driver.quit()
    return all_channels

# %%
k_categories = 5
k_channels_per_category = 10

top_categories = get_top_twitch_categories(k_categories)

channels_by_category = scrape_channels_from_categories(top_categories, k_channels_per_category)
# Out:
# Category: Just Chatting, Link: https://www.twitch.tv/directory/category/just-chatting
# Category: League of Legends, Link: https://www.twitch.tv/directory/category/league-of-legends
# Category: Minecraft, Link: https://www.twitch.tv/directory/category/minecraft
# Category: IRL, Link: https://www.twitch.tv/directory/category/irl
# Category: Borderlands 4, Link: https://www.twitch.tv/directory/category/borderlands-4
# Scraping category: Just Chatting
# Set language filter to English.
# Category: Just Chatting, Channel ID: kaicenat, URL: https://www.twitch.tv/kaicenat
# Category: Just Chatting, Channel ID: cdawg, URL: https://www.twitch.tv/cdawg
# Category: Just Chatting, Channel ID: ishowspeed, URL: https://www.twitch.tv/ishowspeed
# Category: Just Chatting, Channel ID: midnightsumo, URL: https://www.twitch.tv/midnightsumo
# Category: Just Chatting, Channel ID: arky, URL: https://www.twitch.tv/arky
# Category: Just Chatting, Channel ID: nosiiree, URL: https://www.twitch.tv/nosiiree
# Category: Just Chatting, Channel ID: michimochievee, URL: https://www.twitch.tv/michimochievee
# Category: Just Chatting, Channel ID: robcdee, URL: https://www.twitch.tv/robcdee
# Category: Just Chatting, Channel ID: tinakitten, URL: https://www.twitch.tv/tinakitten
# Category: Just Chatting, Channel ID: waterlynn, URL: https://www.twitch.tv/waterlynn
# Scraping category: League of Legends
# English language filter already checked, skipping click.
# Set language filter to English.
# Category: League of Legends, Channel ID: broxah, URL: https://www.twitch.tv/broxah
# Category: League of Legends, Channel ID: lourlo, URL: https://www.twitch.tv/lourlo
# Category: League of Legends, Channel ID: tarzaned, URL: https://www.twitch.tv/tarzaned
# Category: League of Legends, Channel ID: midbeast, URL: https://www.twitch.tv/midbeast
# Category: League of Legends, Channel ID: chubby_squirrelxd, URL: https://www.twitch.tv/chubby_squirrelxd
# Category: League of Legends, Channel ID: viper, URL: https://www.twitch.tv/viper
# Category: League of Legends, Channel ID: paulbelter, URL: https://www.twitch.tv/paulbelter
# Category: League of Legends, Channel ID: sirhcez, URL: https://www.twitch.tv/sirhcez
# Category: League of Legends, Channel ID: lolworldchampionship, URL: https://www.twitch.tv/lolworldchampionship
# Category: League of Legends, Channel ID: wingsofdeath, URL: https://www.twitch.tv/wingsofdeath
# Scraping category: Minecraft
# English language filter already checked, skipping click.
# Set language filter to English.
# Category: Minecraft, Channel ID: masayoshi, URL: https://www.twitch.tv/masayoshi
# Category: Minecraft, Channel ID: 2wintails, URL: https://www.twitch.tv/2wintails
# Category: Minecraft, Channel ID: marymaybe, URL: https://www.twitch.tv/marymaybe
# Category: Minecraft, Channel ID: melizande, URL: https://www.twitch.tv/melizande
# Category: Minecraft, Channel ID: millkberry, URL: https://www.twitch.tv/millkberry
# Category: Minecraft, Channel ID: triciaisabirdy, URL: https://www.twitch.tv/triciaisabirdy
# Category: Minecraft, Channel ID: pewdiepie, URL: https://www.twitch.tv/pewdiepie
# Category: Minecraft, Channel ID: hoef, URL: https://www.twitch.tv/hoef
# Category: Minecraft, Channel ID: mikan, URL: https://www.twitch.tv/mikan
# Category: Minecraft, Channel ID: misamichelle, URL: https://www.twitch.tv/misamichelle
# Scraping category: IRL
# English language filter already checked, skipping click.
# Set language filter to English.
# Category: IRL, Channel ID: chloe__irl, URL: https://www.twitch.tv/chloe__irl
# Category: IRL, Channel ID: digitalnas, URL: https://www.twitch.tv/digitalnas
# Category: IRL, Channel ID: studytme, URL: https://www.twitch.tv/studytme
# Category: IRL, Channel ID: meltislive, URL: https://www.twitch.tv/meltislive
# Category: IRL, Channel ID: widweez, URL: https://www.twitch.tv/widweez
# Category: IRL, Channel ID: primatepaige, URL: https://www.twitch.tv/primatepaige
# Category: IRL, Channel ID: minchu3150, URL: https://www.twitch.tv/minchu3150
# Category: IRL, Channel ID: floppyjimmie, URL: https://www.twitch.tv/floppyjimmie
# Category: IRL, Channel ID: ulumaika, URL: https://www.twitch.tv/ulumaika
# Category: IRL, Channel ID: nomadicgaijin, URL: https://www.twitch.tv/nomadicgaijin
# Scraping category: Borderlands 4
# English language filter already checked, skipping click.
# Set language filter to English.
# Category: Borderlands 4, Channel ID: willneff, URL: https://www.twitch.tv/willneff
# Category: Borderlands 4, Channel ID: datmodz, URL: https://www.twitch.tv/datmodz
# Category: Borderlands 4, Channel ID: pokelawls, URL: https://www.twitch.tv/pokelawls
# Category: Borderlands 4, Channel ID: dizzy, URL: https://www.twitch.tv/dizzy
# Category: Borderlands 4, Channel ID: piratesoftware, URL: https://www.twitch.tv/piratesoftware
# Category: Borderlands 4, Channel ID: grimmmz, URL: https://www.twitch.tv/grimmmz
# Category: Borderlands 4, Channel ID: jihi, URL: https://www.twitch.tv/jihi
# Category: Borderlands 4, Channel ID: sneakylol, URL: https://www.twitch.tv/sneakylol
# Category: Borderlands 4, Channel ID: duncstar, URL: https://www.twitch.tv/duncstar
# Category: Borderlands 4, Channel ID: thedocend, URL: https://www.twitch.tv/thedocend

# %%
channels_df = pd.DataFrame(channels_by_category)
channels_df.to_csv('channels_by_category.csv', index=False)

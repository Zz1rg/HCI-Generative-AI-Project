# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import time
import pandas as pd

# %%
def setup_driver():
    options = webdriver.ChromeOptions()
    options.add_argument('--headless')  # Run in headless mode
    options.add_argument('--no-sandbox')
    options.add_argument('--disable-dev-shm-usage')
    service = Service('C:/Users/user/Desktop/WebScrapingProject/chromedriver.exe')
    driver = webdriver.Chrome(service=service, options=options)
    return driver

# %%
def get_top_twitch_categories(k=10):
    # Set up Chrome WebDriver
    driver = setup_driver()
    
    url = 'https://www.twitch.tv/directory?sort=VIEWER_COUNT'
    driver.get(url)
    time.sleep(3)  # Wait for page to load
    
    # Find category elements
    categories = driver.find_elements(By.XPATH, '//a[contains(@class, "ScCoreLink-sc-16kq0mq-0") and h2]')
    top_k_categories = []
    for cat in categories[:k]:
        # Try to get the category name from a span or h2 element
        try:
            # Sometimes the category name is in a span with data-a-target="tw-core-button-label-text"
            name_elem = cat.find_element(By.XPATH, './/h2')
            if "viewers" in name_elem.text.lower():
                continue  # Skip if it contains viewer count
            name = name_elem.text
            link = cat.get_attribute('href')
            print(f"Category: {name}, Link: {link}")
            top_k_categories.append((name, link))
        except Exception:
            continue
    driver.quit()
    return top_k_categories

# %%
def scrape_channels_from_categories(top_categories, max_channels_per_category=20):
    driver = setup_driver()
    all_channels = []

    # top_categories = top_categories[:1]  # Limit to top 1 category for brevity
    for name, link in top_categories:
        print(f"Scraping category: {name}")
        driver.get(link + "?sort=VIEWER_COUNT")
        time.sleep(3)  # Wait for page to load

        # Set language filter to English if the option is available
        try:
            # Open the language filter menu first
            filter_button = driver.find_element(
                By.XPATH,
                '//button[.//div[@data-a-target="tw-core-button-label-text" and contains(text(), "Language")]]'
            )
            filter_button.click()
            time.sleep(1)
            english_label = driver.find_element(
                By.XPATH,
                '//label[.//div[text()="English"]]'
            )
            # Find the associated checkbox input
            checkbox = english_label.find_element(
                By.XPATH,
                './preceding-sibling::input[@type="checkbox"]'
            )
            # Only click if not already checked
            if not checkbox.is_selected():
                english_label.click()
                time.sleep(1)  # Wait for the page to reload with the filter applied
            else:
                print("English language filter already checked, skipping click.")
            print("Set language filter to English.")
        except Exception:
            print("English language filter not found or could not be set.")

        # Scroll to load more channels if needed
        last_height = driver.execute_script("return document.body.scrollHeight")
        while True:
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(2)
            new_height = driver.execute_script("return document.body.scrollHeight")
            if new_height == last_height or len(driver.find_elements(
                By.XPATH, '//a[@data-a-target="preview-card-channel-link"]')) >= max_channels_per_category:
                break
            last_height = new_height

        channel_elements = driver.find_elements(
            By.XPATH, '//a[@data-a-target="preview-card-channel-link"]')
        for elem in channel_elements[:max_channels_per_category]:
            href = elem.get_attribute('href')
            channelId = href.split('/')[-1]
            print(f"Category: {name}, Channel ID: {channelId}, URL: {href}")
            all_channels.append({'category': name, 'href': href, 'channelId': channelId})

    driver.quit()
    return all_channels

# %%
k_categories = 10
k_channels_per_category = 5

top_categories = get_top_twitch_categories(k_categories)

channels_by_category = scrape_channels_from_categories(top_categories, k_channels_per_category)
# Out:
# Category: VALORANT, Link: https://www.twitch.tv/directory/category/valorant
# Category: Just Chatting, Link: https://www.twitch.tv/directory/category/just-chatting
# Category: Grand Theft Auto V, Link: https://www.twitch.tv/directory/category/grand-theft-auto-v
# Category: League of Legends, Link: https://www.twitch.tv/directory/category/league-of-legends
# Category: Dota 2, Link: https://www.twitch.tv/directory/category/dota-2
# Category: Counter-Strike, Link: https://www.twitch.tv/directory/category/counter-strike
# Category: Call of Duty: Black Ops 7, Link: https://www.twitch.tv/directory/category/call-of-duty-black-ops-7
# Category: EA Sports FC 26, Link: https://www.twitch.tv/directory/category/ea-sports-fc-26
# Category: Ghost of Yōtei, Link: https://www.twitch.tv/directory/category/ghost-of-yotei
# Category: World of Tanks, Link: https://www.twitch.tv/directory/category/world-of-tanks
# Scraping category: VALORANT
# Set language filter to English.
# Category: VALORANT, Channel ID: valorant, URL: https://www.twitch.tv/valorant
# Category: VALORANT, Channel ID: tenz, URL: https://www.twitch.tv/tenz
# Category: VALORANT, Channel ID: gofns, URL: https://www.twitch.tv/gofns
# Category: VALORANT, Channel ID: ohnepixel, URL: https://www.twitch.tv/ohnepixel
# Category: VALORANT, Channel ID: tarik, URL: https://www.twitch.tv/tarik
# Scraping category: Just Chatting
# English language filter already checked, skipping click.
# Set language filter to English.
# Category: Just Chatting, Channel ID: jasontheween, URL: https://www.twitch.tv/jasontheween
# Category: Just Chatting, Channel ID: stableronaldo, URL: https://www.twitch.tv/stableronaldo
# Category: Just Chatting, Channel ID: quin69, URL: https://www.twitch.tv/quin69
# Category: Just Chatting, Channel ID: lacy, URL: https://www.twitch.tv/lacy
# Category: Just Chatting, Channel ID: silky, URL: https://www.twitch.tv/silky
# Scraping category: Grand Theft Auto V
# English language filter already checked, skipping click.
# Set language filter to English.
# Category: Grand Theft Auto V, Channel ID: hutchmf, URL: https://www.twitch.tv/hutchmf
# Category: Grand Theft Auto V, Channel ID: abdulhd, URL: https://www.twitch.tv/abdulhd
# Category: Grand Theft Auto V, Channel ID: penta, URL: https://www.twitch.tv/penta
# Category: Grand Theft Auto V, Channel ID: thebigmeech, URL: https://www.twitch.tv/thebigmeech
# Category: Grand Theft Auto V, Channel ID: mrgibbon, URL: https://www.twitch.tv/mrgibbon
# Scraping category: League of Legends
# English language filter already checked, skipping click.
# Set language filter to English.
# Category: League of Legends, Channel ID: caedrel, URL: https://www.twitch.tv/caedrel
# Category: League of Legends, Channel ID: forsen, URL: https://www.twitch.tv/forsen
# Category: League of Legends, Channel ID: nattynattlol, URL: https://www.twitch.tv/nattynattlol
# Category: League of Legends, Channel ID: lol_nemesis, URL: https://www.twitch.tv/lol_nemesis
# Category: League of Legends, Channel ID: drututt, URL: https://www.twitch.tv/drututt
# Scraping category: Dota 2
# English language filter already checked, skipping click.
# Set language filter to English.
# Category: Dota 2, Channel ID: gorgc, URL: https://www.twitch.tv/gorgc
# Category: Dota 2, Channel ID: qojqva, URL: https://www.twitch.tv/qojqva
# Category: Dota 2, Channel ID: cr1tdota, URL: https://www.twitch.tv/cr1tdota
# Category: Dota 2, Channel ID: wagamamatv, URL: https://www.twitch.tv/wagamamatv
# Category: Dota 2, Channel ID: synderen, URL: https://www.twitch.tv/synderen
# Scraping category: Counter-Strike
# English language filter already checked, skipping click.
# Set language filter to English.
# Category: Counter-Strike, Channel ID: franzj, URL: https://www.twitch.tv/franzj
# Category: Counter-Strike, Channel ID: furi, URL: https://www.twitch.tv/furi
# Category: Counter-Strike, Channel ID: dima_wallhacks, URL: https://www.twitch.tv/dima_wallhacks
# Category: Counter-Strike, Channel ID: neok, URL: https://www.twitch.tv/neok
# Category: Counter-Strike, Channel ID: anomaly, URL: https://www.twitch.tv/anomaly
# Scraping category: Call of Duty: Black Ops 7
# English language filter already checked, skipping click.
# Set language filter to English.
# Category: Call of Duty: Black Ops 7, Channel ID: timthetatman, URL: https://www.twitch.tv/timthetatman
# Category: Call of Duty: Black Ops 7, Channel ID: nadeshot, URL: https://www.twitch.tv/nadeshot
# Category: Call of Duty: Black Ops 7, Channel ID: callofduty, URL: https://www.twitch.tv/callofduty
# Category: Call of Duty: Black Ops 7, Channel ID: swagg, URL: https://www.twitch.tv/swagg
# Category: Call of Duty: Black Ops 7, Channel ID: symfuhny, URL: https://www.twitch.tv/symfuhny
# Scraping category: EA Sports FC 26
# English language filter already checked, skipping click.
# Set language filter to English.
# Category: EA Sports FC 26, Channel ID: auziomf, URL: https://www.twitch.tv/auziomf
# Category: EA Sports FC 26, Channel ID: easportsfc, URL: https://www.twitch.tv/easportsfc
# Category: EA Sports FC 26, Channel ID: nepenthez, URL: https://www.twitch.tv/nepenthez
# Category: EA Sports FC 26, Channel ID: fuji720x, URL: https://www.twitch.tv/fuji720x
# Category: EA Sports FC 26, Channel ID: anthonydaytv, URL: https://www.twitch.tv/anthonydaytv
# Scraping category: Ghost of Yōtei
# English language filter already checked, skipping click.
# Set language filter to English.
# Category: Ghost of Yōtei, Channel ID: elajjaz, URL: https://www.twitch.tv/elajjaz
# Category: Ghost of Yōtei, Channel ID: missmikkaa, URL: https://www.twitch.tv/missmikkaa
# Category: Ghost of Yōtei, Channel ID: barbarousking, URL: https://www.twitch.tv/barbarousking
# Category: Ghost of Yōtei, Channel ID: dansgaming, URL: https://www.twitch.tv/dansgaming
# Category: Ghost of Yōtei, Channel ID: distortion2, URL: https://www.twitch.tv/distortion2
# Scraping category: World of Tanks
# English language filter already checked, skipping click.
# Set language filter to English.
# Category: World of Tanks, Channel ID: worldoftanks, URL: https://www.twitch.tv/worldoftanks
# Category: World of Tanks, Channel ID: quickybaby, URL: https://www.twitch.tv/quickybaby
# Category: World of Tanks, Channel ID: skill4ltu, URL: https://www.twitch.tv/skill4ltu
# Category: World of Tanks, Channel ID: dakillzor, URL: https://www.twitch.tv/dakillzor
# Category: World of Tanks, Channel ID: gotyoubaby, URL: https://www.twitch.tv/gotyoubaby

# %%
channels_df = pd.DataFrame(channels_by_category)
channels_df.to_csv('../data/channels_by_category.csv', index=False)
